# %% [markdown]
# # Importanto bibliotecas utilizadas

# %%
#### Definição do Frame Work ####

from CoolProp.CoolProp import PropsSI
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from CoolProp.Plots import PropertyPlot
from utils import Experimento

# %% [markdown]
# # Experimento 3

# %% [markdown]
# ## Convecção forçada

# %% [markdown]
# ### R134a

# %%
# definicao de dados experimentais
Temp3_1 = {
    'Ts1': 6,
    'Ts2': 51,
    'Ts3': 32,
    'Ts4': 5,
}

Press3_1 = {
    'Ps1': 2.25,
    'Ps2': 13,
    'Ps3': 11,
    'Ps4': 1,
}

I = 4

Q = 4.2e-6

fluido = "R134a"

# %%
exp3_1 = Experimento(Temp3_1,Press3_1,I,Q, fluido, correcao=True)
exp3_1.conv_input_df
# Out:
#    Temperatura  Pressao  Entalpia  Densidade  Calor Esp.  Vasao massica
# 0          6.0      3.3     403.1       15.8       905.8       0.000066
# 1         60.2     14.0     433.9       66.6      1192.8       0.000280
# 2         32.0     12.0     244.6     1182.2      1450.2       0.004965
# 3          5.0      3.3     244.6       74.1       907.4       0.000311

# %%
exp3_1.analise_defaut()
exp3_1.output_df
# Out:
#         Propriedade   Valor
# 0       delta_T_eva     1.0
# 1      delta_T_cond   -28.2
# 2       delta_P_eva     0.0
# 3      delta_P_cond    -2.0
# 4               COP     5.1
# 5          pot_comp   508.0
# 6  sub_resfriamento    14.4
# 7   sup_aquecimento     3.0
# 8    ef_isentropica     1.0
# 9   trab_compressao  5.3293

# %%
exp3_1.plot_diagrama_ph()
# Out:
# /home/thiago/anaconda3/envs/default/lib/python3.9/site-packages/CoolProp/Plots/Common.py:655: UserWarning: An error occurred for inputs 8771670.263783, 2426.329225 with index (248,): unable to solve 1phase PY flash with Tmin=169.849, Tmax=682.5 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [247.563 J/mol/K] is above the maximum value of 247.390746622 J/mol/K
#   warnings.warn(
# /home/thiago/anaconda3/envs/default/lib/python3.9/site-packages/CoolProp/Plots/Common.py:655: UserWarning: An error occurred for inputs 9133000.049092, 2426.329225 with index (249,): unable to solve 1phase PY flash with Tmin=169.849, Tmax=682.5 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [247.563 J/mol/K] is above the maximum value of 246.954593629 J/mol/K
#   warnings.warn(
# ...

# %%
exp3_1.plot_sub_resfriamento_vs_COP(10,30)

# %%
exp3_1.plot_calor_evap_vs_P(0.35e6,0.4e6)

# %% [markdown]
# ### Amônia

# %%
fluido = "Ammonia"

exp3_1_2 = Experimento(Temp3_1,Press3_1,I,Q, fluido, correcao=True)
exp3_1_2.conv_input_df
# Out:
#    Temperatura  Pressao  Entalpia  Densidade  Calor Esp.  Vasao massica
# 0          6.0      3.3    1632.5        2.5      2461.2       0.000011
# 1        115.7     14.0    1856.4        7.8      2539.1       0.000033
# 2         32.0     12.0    1635.6        9.3      3254.6       0.000039
# 3          5.0      3.3    1635.6        2.5      2469.3       0.000010

# %%
exp3_1_2.analise_defaut()
exp3_1_2.output_df
# Out:
#         Propriedade   Valor
# 0       delta_T_eva     1.0
# 1      delta_T_cond   -83.7
# 2       delta_P_eva     0.0
# 3      delta_P_cond    -2.0
# 4               COP    -0.0
# 5          pot_comp   508.0
# 6  sub_resfriamento    -1.0
# 7   sup_aquecimento    13.1
# 8    ef_isentropica     1.0
# 9   trab_compressao  4.8552

# %% [markdown]
# ## Convecção Natural

# %% [markdown]
# ### R134a

# %%
# definicao de dados experimentais
Temp3_2 = {
    'Ts1': 7,
    'Ts2': 57,
    'Ts3': 46,
    'Ts4': 7,
}

Press3_2 = {
    'Ps1': 2.5,
    'Ps2': 14.5,
    'Ps3': 13,
    'Ps4': 1,
}

I = 4.5

Q = 4.2e-6

fluido = "R134a"

# %%
exp3_2 = Experimento(Temp3_2,Press3_2,I,Q, fluido, correcao=True)
exp3_2.conv_input_df
# Out:
#    Temperatura  Pressao  Entalpia  Densidade  Calor Esp.  Vasao massica
# 0          7.0      3.5     403.3       17.0       917.3       0.000072
# 1         63.5     15.5     434.4       75.0      1241.4       0.000315
# 2         46.0     14.0     265.4     1122.6      1531.0       0.004715
# 3          7.0      3.5     265.4       55.6       917.3       0.000233

# %%
exp3_2.analise_defaut()
exp3_2.output_df
# Out:
#         Propriedade   Valor
# 0       delta_T_eva     0.0
# 1      delta_T_cond   -17.5
# 2       delta_P_eva     0.0
# 3      delta_P_cond    -1.5
# 4               COP     4.4
# 5          pot_comp   571.5
# 6  sub_resfriamento     6.5
# 7   sup_aquecimento     1.9
# 8    ef_isentropica     1.0
# 9   trab_compressao  6.0162

# %%
exp3_2.plot_diagrama_ph()
# Out:
# /home/thiago/anaconda3/envs/default/lib/python3.9/site-packages/CoolProp/Plots/Common.py:655: UserWarning: An error occurred for inputs 8771670.263783, 2426.329225 with index (248,): unable to solve 1phase PY flash with Tmin=169.849, Tmax=682.5 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [247.563 J/mol/K] is above the maximum value of 247.390746622 J/mol/K
#   warnings.warn(
# /home/thiago/anaconda3/envs/default/lib/python3.9/site-packages/CoolProp/Plots/Common.py:655: UserWarning: An error occurred for inputs 9133000.049092, 2426.329225 with index (249,): unable to solve 1phase PY flash with Tmin=169.849, Tmax=682.5 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [247.563 J/mol/K] is above the maximum value of 246.954593629 J/mol/K
#   warnings.warn(
# ...

# %% [markdown]
# ### Amônia

# %%
fluido = "Ammonia"

exp3_2_2 = Experimento(Temp3_2,Press3_2,I,Q, fluido, correcao=True)
exp3_2_2.conv_input_df
# Out:
#    Temperatura  Pressao  Entalpia  Densidade  Calor Esp.  Vasao massica
# 0          7.0      3.5    1632.8        2.7      2488.5       0.000011
# 1        119.4     15.5    1861.7        8.6      2566.4       0.000036
# 2         46.0     14.0    1666.3       10.3      3141.6       0.000043
# 3          7.0      3.5    1666.3        2.6      2488.5       0.000011

# %%
exp3_2_2.analise_defaut()
exp3_2_2.output_df
# Out:
#         Propriedade   Valor
# 0       delta_T_eva     0.0
# 1      delta_T_cond   -73.4
# 2       delta_P_eva     0.0
# 3      delta_P_cond    -1.5
# 4               COP    -0.1
# 5          pot_comp   571.5
# 6  sub_resfriamento    -9.7
# 7   sup_aquecimento    12.2
# 8    ef_isentropica     1.0
# 9   trab_compressao  5.4352
